# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('supermarket.csv')
df
# Out:
#      department1 department2 department3 department4 department5 department6  \
# 0              ?           ?           ?           ?           ?           ?
# 1              t           ?           ?           ?           ?           ?
# 2              ?           ?           ?           ?           ?           ?
# 3              t           ?           ?           ?           ?           ?
# 4              ?           ?           ?           ?           ?           ?
# ...          ...         ...         ...         ...         ...         ...
# 4622           ?           ?           ?           ?           ?           ?
# 4623           ?           ?           ?           t           ?           ?
# 4624           ?           ?           ?           ?           ?           ?
# 4625           ?           ?           ?           ?           ?           ?
# 4626           t           ?           ?           ?           ?           ?
#
# ...

# %%
# Setting option to show all the columns
pd.set_option('display.max_columns', None)

df
# Out:
#      department1 department2 department3 department4 department5 department6  \
# 0              ?           ?           ?           ?           ?           ?
# 1              t           ?           ?           ?           ?           ?
# 2              ?           ?           ?           ?           ?           ?
# 3              t           ?           ?           ?           ?           ?
# 4              ?           ?           ?           ?           ?           ?
# ...          ...         ...         ...         ...         ...         ...
# 4622           ?           ?           ?           ?           ?           ?
# 4623           ?           ?           ?           t           ?           ?
# 4624           ?           ?           ?           ?           ?           ?
# 4625           ?           ?           ?           ?           ?           ?
# 4626           t           ?           ?           ?           ?           ?
#
# ...

# %%
# Replacing all the ? with NaN
df.replace('?', np.nan, inplace=True)
df
# Out:
#      department1 department2 department3 department4 department5 department6  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1              t         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3              t         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 4622         NaN         NaN         NaN         NaN         NaN         NaN
# 4623         NaN         NaN         NaN           t         NaN         NaN
# 4624         NaN         NaN         NaN         NaN         NaN         NaN
# 4625         NaN         NaN         NaN         NaN         NaN         NaN
# 4626           t         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
# Applying Apriori Principle to find the most frequent itemsets and association rules
one_rules = df.apply(lambda col: col.eq('t').sum(), axis=0).nlargest(10)
rules = one_rules.to_dict()
rules
# Out:
# {"'bread and cake'": 3330,
#  'fruit': 2962,
#  'vegetables': 2961,
#  'milk-cream': 2939,
#  "'baking needs'": 2795,
#  "'frozen foods'": 2717,
#  'biscuits': 2605,
#  'juice-sat-cord-ms': 2463,
#  "'party snack foods'": 2330,
#  'margarine': 2288}

# %%
def support(itemset, otherset):
    merged = itemset + otherset
    return df.groupby(merged).size()

# %%
# Applying Apriori Algorithm for two items dataset using the items in above rules dictionary
items = list(rules.keys())

for i in range(len(items)):
    for j in range(i+1, len(items)):
        item1 = [items[i]]
        item2 = [items[j]]

        # Calculating support for item1 and item2
        support_item1 = support(item1, item2)
        support_item2 = support(item2, item1)

        print(support_item1)
# Out:
# ["'bread and cake'"]
# ['fruit']
# 'bread and cake'  fruit
# t                 t        2325
# dtype: int64
# ["'bread and cake'"]
# ['vegetables']
# 'bread and cake'  vegetables
# t                 t             2298
# dtype: int64
# ["'bread and cake'"]
# ['milk-cream']
# 'bread and cake'  milk-cream
# t                 t             2337
# dtype: int64
# ["'bread and cake'"]
# ["'baking needs'"]
# 'bread and cake'  'baking needs'
# t                 t                 2191
# dtype: int64
# ["'bread and cake'"]
# ["'frozen foods'"]
# 'bread and cake'  'frozen foods'
# t                 t                 2129
# dtype: int64
# ["'bread and cake'"]
# ['biscuits']
# 'bread and cake'  biscuits
# t                 t           2083
# dtype: int64
# ["'bread and cake'"]
# ['juice-sat-cord-ms']
# 'bread and cake'  juice-sat-cord-ms
# t                 t                    1869
# dtype: int64
# ["'bread and cake'"]
# ["'party snack foods'"]
# 'bread and cake'  'party snack foods'
# ...
